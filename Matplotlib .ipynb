# %% [markdown]
# # Matplotlib

# %% [markdown]
# It is a very powerful plotting library useful for those working with Python and NumPy.
#
# Matplotlib is an amazing visualization library in Python for 2D plots of arrays. Matplotlib is a multi-platform data visualization library built on NumPy arrays and designed to work with the broader SciPy stack
#
# To make necessary statistical inferences, it becomes necessary to visualize your data and Matplotlib is one such solution for the Python users.
#
# One of the greatest benefits of visualization is that it allows us visual access to huge amounts of data in easily digestible visuals. Matplotlib consists of several plots like line, bar, scatter, histogram etc.

# %% [markdown]
# Matplotlib comes with a wide variety of plots. Plots helps to understand trends, patterns, and to make correlations. They’re typically instruments for reasoning about quantitative information.

# %% [markdown]
# # Importing matplotlib :
#
# from matplotlib import pyplot as plt
#
# or
#
# import matplotlib.pyplot as plt

# %% [markdown]
# list of all the methods
#
#         plot(x-axis values, y-axis values) — plots a simple line graph with x-axis values against y-axis values
#
# show() — displays the graph
#
# title(“string”) — set the title of the plot as specified by the string
#
# xlabel(“string”) — set the label for x-axis as specified by the string
#
# ylabel(“string”) — set the label for y-axis as specified by the string
#
# figure() — used to control a figure level attributes
#
# subplot(nrows, ncols, index) — Add a subplot to the current figure
#
# suptitle(“string”) — It adds a common title to the figure specified by the string
#
# subplots(nrows, ncols, figsize) — a convenient way to create subplots, in a single call. It returns a tuple of a figure and number of axes.
#
# set_title(“string”) — an axes level method used to set the title of subplots in a figure
#
# bar(categorical variables, values, color) — used to create vertical bar graphs
#
# barh(categorical variables, values, color) — used to create horizontal bar graphs
#
# legend(loc) — used to make legend of the graph
#
# xticks(index, categorical variables) — Get or set the current tick locations and labels of the x-axis
#
# pie(value, categorical variables) — used to create a pie chart
#
# hist(values, number of bins) — used to create a histogram
#
# xlim(start value, end value) — used to set the limit of values of the x-axis
#
# ylim(start value, end value) — used to set the limit of values of the y-axis
#
# scatter(x-axis values, y-axis values) — plots a scatter plot with x-axis values
# against y-axis values
#
# axes() — adds an axes to the current figure
#
# set_xlabel(“string”) — axes level method used to set the x-label of the plot specified as a string
#
# set_ylabel(“string”) — axes level method used to set the y-label of the plot specified as a string
#
# scatter3D(x-axis values, y-axis values) — plots a three-dimensional scatter plot with x-axis values against y-axis values
#
# plot3D(x-axis values, y-axis values) — plots a three-dimensional line graph with x-axis values against y-axis values

# %% [markdown]
# Creating different types of graphs with Pyplot
# 1. Bar Graph
# 2. Pie Chart
# 3. Histogram
# 4. Scater Plot and 3D plot

# %% [markdown]
# ## Line Plot

# %%
# importing matplotlib module 
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
# or we can use import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4],[1,24,9,16])
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,6])
plt.title("First plot")
plt.xlabel("X-Lable")
plt.ylabel("Y-label")
plt.show()

# %%
plt.figure(figsize=(15,5))#passing the values as a tuple of the length of rows and columns to the argument
plt.plot([1,2,3,4],[1,24,9,16])
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,6],"go")#go which means green circles
            # The default format is b- which means a solid blue line
plt.title("First plot")
plt.xlabel("X-Lable")
plt.ylabel("Y-label")
plt.show()

# %%
x=np.arange(1,5)
y=x**3
plt.plot([1,2,3,4],[1,4,9,6],'go',x,y,'r^')
plt.title("First plot")
plt.xlabel("X-Lable")
plt.ylabel("Y-label")
plt.show()

# %%
  
# x-axis values 
x = [5, 2, 9, 4, 7] 
  
# Y-axis values 
y = [10, 5, 8, 4, 2] 

#plt.figure(figsize=(10,4))
# Function to plot 
plt.plot(x,y) 
  
# function to show the plot 
plt.show()

# %% [markdown]
# # Bar

# %%
# x-axis values 
x = [5, 2, 9, 4, 7] 
  
# Y-axis values 
y = [10, 5, 8, 4, 2] 
  
# Function to plot the bar 
plt.bar(x,y) 
  
# function to show the plot 
plt.show()

# %% [markdown]
# Histogram

# %%
# Y-axis values 
y = [10, 5, 8, 4, 2] 
  
# Function to plot histogram 
plt.hist(y) 
  
# Function to show the plot 
plt.show()

# %% [markdown]
# Scatter Plot

# %%
# x-axis values 
x = [5, 2, 9, 4, 7] 
  
# Y-axis values 
y = [10, 5, 8, 4, 2] 
  
# Function to plot scatter 
plt.scatter(x, y) 
  
# function to show the plot 
plt.show()

# %% [markdown]
# # Different plotting using pandas and matplotlib

# %% [markdown]
# Basic plotting: In this basic plot we can use the randomly generated data to plot graph using series and matplotlib.filter_none,brightness_4

# %%
# import libraries 
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np 
#ts is time series  
ts = pd.Series(np.random.randn(100), index = pd.date_range( 
                                '1/1/2005', periods = 100)) 
ts = ts.cumsum() #cumsum() function is used when we want to compute the cumulative sum of array elements over a given axis
ts.plot() 
  
plt.show() 
#A time series is a series of data points, 
#which are listed (or indexed) in time order. Usually, a time series is a sequence of values, which are equally spaced points in time

# %% [markdown]
# ### Plot of different data: Using more than one list of data in a plot

# %%
#ts = pd.Series(np.random.randn(1000), index = pd.date_range( 
  #                              '1/1/2000', periods = 1000)) 
  
df = pd.DataFrame(np.random.randn(1000, 4),  
   index = pd.date_range('1/1/2000', periods = 1000), columns = list('ABCD')) #
  
df = df.cumsum() 
#print(df)
plt.figure() 
df.plot() 
plt.show()

# %% [markdown]
# ## Plot on given axis:
# We can explicitly define the name of axis and plot the data on the basis of this axis.

# %%
ts = pd.Series(np.random.randn(1000), index = pd.date_range( 
                                '1/1/2000', periods = 1000)) 
  
df = pd.DataFrame(np.random.randn(1000, 4), index = ts.index, 
                                      columns = list('ABCD')) 
  
df3 = pd.DataFrame(np.random.randn(1000, 2), 
               columns =['B', 'C']).cumsum() 
  
df3['A'] = pd.Series(list(range(len(df)))) 
df3.plot(x ='A', y ='B') 
plt.show()

# %% [markdown]
# # Bar plot using matplotlib:
#
# Find different types of bar plot to clearly understand the behaviour of given data.

# %%
ts = pd.Series(np.random.randn(1000), index = pd.date_range( 
                                '1/1/2000', periods = 1000)) 
  
df = pd.DataFrame(np.random.randn(1000, 4), index = ts.index, 
                                      columns = list('ABCD')) 
  
df3 = pd.DataFrame(np.random.randn(1000, 2), 
               columns =['B', 'C']).cumsum() 
  
df3['A'] = pd.Series(list(range(len(df)))) 
df3.iloc[5].plot.bar() 
plt.axhline(0, color ='k') 
  
plt.show()

# %%
div=["Div-A","Div-B","Div-C","Div-D","Div-E"]
div_avg_marks=[78,82,73,65,68]
plt.bar(div,div_avg_marks,color='green')
plt.title("Bar graph")
plt.xlabel("Division")
plt.ylabel("Marks")
plt.show()

# %%
div=["Div-A","Div-B","Div-C","Div-D","Div-E"]
div_avg_marks=[78,82,73,65,68]
plt.barh(div,div_avg_marks,color='green')
plt.title("Bar graph")
plt.xlabel("Division")
plt.ylabel("Marks")
plt.show()

# %%
#To make horizontal bar graphs use method barh() Also we can pass an argument
#(with its value)xerr oryerr (in case of the above vertical bar
div=["Div-A","Div-B","Div-C","Div-D","Div-E"]
div_avg_marks=[78,82,73,65,68]
variance=[5,8,7,6,4]
plt.barh(div,div_avg_marks,xerr=variance,color='green')
plt.title("Bar graph")
plt.xlabel("Division")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
# Horizontally stacked bar graphs

# %%
div=["Div-A","Div-B","Div-C","Div-D","Div-E"]
div_avg_marks=[78,82,73,65,68]
boys_avg_marks=[68,67,77,61,70]

index=np.arange(5)
width=0.30
plt.bar(div,div_avg_marks,width,color='green',label='Division Marks')
plt.bar(index+width,boys_avg_marks,width,color='blue',label='Boys marks')
plt.title("Horizontally Stacked Bar Graph")
plt.ylabel("Marks")
plt.xlabel("Division")
plt.show()

# %% [markdown]
# vertically stack the bar graphs together, we can use an argument bottom and mention the bar graph which we want to stack below as its value.

# %%
div=["Div-A","Div-B","Div-C","Div-D","Div-E"]
girls_avg_marks=[72,97,69,69,66]
boys_avg_marks=[68,67,77,61,70]

index=np.arange(5)
width=0.30
plt.bar(index,boys_avg_marks,width,color='green',label='Boys Marks')
plt.bar(index,girls_avg_marks,width,color='red',label='Girls Marks',bottom=boys_avg_marks)
plt.title("Vertically Stacked Bar Graph")
plt.ylabel("Marks")
plt.xlabel("Division")
plt.xticks(index,div)# gives the marking on x axis as Div-A etc....
plt.legend(loc='best')# gives the best fit to display the plot name on top right corner
plt.show()

# %% [markdown]
# Histograms

# %%
x=np.random.randn(1000)
plt.title("Histogram")
plt.xlabel("Random Data")
plt.ylabel("Frequency")
plt.hist(x,10)
plt.show()

# %%
df4 = pd.DataFrame({'a': np.random.randn(1000) + 1,  
                    'b': np.random.randn(1000),  
                    'c': np.random.randn(1000) - 1}, 
                           columns =['a', 'b', 'c']) 
plt.figure() 
  
df4.plot.hist(alpha = 0.10) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3d0d89d930d5> in <module>
# ----> 1 df4 = pd.DataFrame({'a': np.random.randn(1000) + 1,
#       2                     'b': np.random.randn(1000),
#       3                     'c': np.random.randn(1000) - 1},
#       4                            columns =['a', 'b', 'c'])
#       5 plt.figure()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Box plot using Series and matplotlib: Use box to plot the data of dataframe

# %%
df = pd.DataFrame(np.random.rand(10, 5),  
      columns =['A', 'B', 'C', 'D', 'E']) 
  
df.plot.box() 
plt.show()

# %% [markdown]
# Density plot

# %%
df = pd.DataFrame(np.random.rand(10, 5),  
      columns =['A', 'B', 'C', 'D', 'E']) 
  
ser = pd.Series(np.random.randn(1000)) 
ser.plot.kde() 
  
plt.show()

# %% [markdown]
# Area plot using matplotlib

# %%
df = pd.DataFrame(np.random.rand(10, 5),  
       columns =['A', 'B', 'C', 'D', 'E']) 
  
df.plot.area() 
plt.show()

# %% [markdown]
# Scatter plot

# %%
height=np.array([167,170,149,165,155,180,166,146,159,185,145,168,172,181,169])
weight=np.array([86,74,66,78,68,79,90,73,70,88,66,84,67,84,77])
plt.xlim(140,200)
plt.ylim(60,100)
plt.scatter(height,weight)
plt.title("Scatter Plot")
plt.xlabel("HEight")
plt.ylabel("Weight")
plt.show()
# xlim() and ylim() methods to set the limits of X-axis and Y-axis respectively.

# %%
df = pd.DataFrame(np.random.rand(500, 2), 
           columns =['a', 'b']) 
  
df.plot.scatter(x ='a', y ='b') 
plt.show()

# %% [markdown]
# # 3D Ploting
#
# Three-dimensional axes is created by passing the keyword projection='3d' to the axes() method of Pyplot module.
#
# Once the object instance is created, we pass our arguments height and weight to scatter3D() method.
#
# First import the module mplot3d

# %%
from mpl_toolkits import mplot3d

ax=plt.axes(projection='3d')
ax.scatter3D(height,weight)
ax.set_xlabel("Height")
ax.set_ylabel("weight")
plt.show()

# %% [markdown]
# simple line graph can be ploted in 3D
#
# Here instead of scatter3D() we use method plot3D()

# %%
ax=plt.axes(projection='3d')
ax.plot3D(height,weight)# Simple line graph
ax.set_xlabel("Height")
ax.set_ylabel("weight")
plt.show()

# %% [markdown]
# Hexagonal Bin Plot

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns =['a', 'b']) 
  
df['a'] = df['a'] + np.arange(1000) 
df.plot.hexbin(x ='a', y ='b', gridsize = 25) 
plt.show()

# %% [markdown]
# Pie plot

# %%
series = pd.Series(3 * np.random.rand(4), 
  index =['a', 'b', 'c', 'd'], name ='series') 
  
series.plot.pie(figsize =(4, 4)) 
plt.show()

# %% [markdown]
# # Matplotlib Sub plotting
#
# Plotting using Object Oriented(OO) API in matplotlib is an easy approach to plot graphs and other data visualization methods.
#
# The subplot() method takes three arguments: they are nrows, ncols and index
#
# They indicate the number of rows, number of columns and the index number of the sub-plot.
#
# we have separately used title()method for both the subplots. We use suptitle() method to make a centralized title for the figure.
#
# The simple syntax to create the class and object for sub-plotting is –
#
#
# class_name, object_name = matplotlib.pyplot.subplots(‘no_of_rows’, ‘no_of_columns’)

# %%
x=np.arange(1,5)
y=x**3
plt.subplot(1,2,1)
plt.plot([1,2,3,4],[1,4,9,6],"go")
plt.title("First Subplot")

plt.subplot(1,2,2)
plt.plot(x,y,'r^')
plt.title("Second Subplot")
plt.show()

# %%
x=np.arange(1,5)
y=x**3
plt.subplot(2,1,1)
plt.plot([1,2,3,4],[1,4,9,6],"go")
plt.title("First Subplot")

plt.subplot(2,1,2)
plt.plot(x,y,'r^')
plt.title("Second Subplot")
plt.show()

# %%
x=np.arange(1,5)
y=x**3
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(6,6))
ax[0,1].plot([1,2,3,4],[1,4,9,6],'go')
ax[1,0].plot(x,y,'r^')
ax[0,1].set_title("Square")
ax[1,0].set_title("Cubes")
plt.show()

# %%
# defining the values of X 
x =[0, 1, 2, 3, 4, 5, 6] 
  
# defining the value of Y 
y =[0, 1, 3, 6, 9, 12, 17] 
  
# creating the canvas with class 'fig' 
# and it's object 'axes' with '1' row  
# and '2' columns 
fig, axes = plt.subplots(1, 2) 
#The subplot() method takes three arguments: they are nrows, ncols and index  
# plotting graph for 1st column 
axes[0].plot(x, y, 'g--o') 
  
# plotting graph for second column 
axes[1].plot(y, x, 'm--o') 
  
# Gives a clean look to the graphs 
fig.tight_layout()

# %%
# defining the values of X 
x =[0, 1, 2, 3, 4, 5, 6] 
  
# defining the value of Y 
y =[0, 1, 3, 6, 9, 12, 17] 
  
# creating the canvas with class 'fig' 
# and it's object 'axes' with '1' row  
# and '2' columns 
fig, axes = plt.subplots(2, 2) 
  
# plotting graph for 1st element 
axes[0, 0].plot(x, y, 'g--o') 
  
# plotting graph for 2nd element 
axes[0, 1].plot(y, x, 'm--o') 
  
# plotting graph for 3rd element 
axes[1, 0].plot(x, y, 'b--o') 
  
# plotting graph for 4th element 
axes[1, 1].plot(y, x, 'r--o') 
  
# Gives a clean look to the graphs 
fig.tight_layout()

# %% [markdown]
# ## Working with PNG Images using Matplotlib
# Portable Network Graphic (PNG)

# %%
import matplotlib.image as img 
  
# reading jpg image file 
im = img.imread('photo.jpg') 
  
# show image 
plt.imshow(im)

# %% [markdown]
# Applying pseudocolor to image
#
# Pseudocolor is useful for enhancing contrast of image.

# %%
# reading jpg image 
im = img.imread('photo.jpg') 
  
# applying pseudocolor  
# default value of colormap is used. 
lum = im[:, :, 0] 
  
# show image 
plt.imshow(lum)

# %% [markdown]
# We can provide another value to colormap with colorbar.

# %%
# reading jpg image 
im = img.imread('photo.jpg') 
lum = im[:, :, 0] 
  
# setting colormap as hot 
plt.imshow(lum, cmap ='hot') 
plt.colorbar()

# %% [markdown]
# ### Interpolation Schemes:
# Interpolation calculates what the color or value of a pixel “should” be and this needed when we resize the image but want the same information.

# %%
from PIL import Image  
#import matplotlib.pyplot as plt 
  
# reading png image  file 
img = Image.open('photo.jpg') 
  
# resizing the image 
img.thumbnail((50, 50), Image.ANTIALIAS) 
imgplot = plt.imshow(img)

# %% [markdown]
#  Here, ‘bicubic’ value is used for interpolation

# %%
# reading image 
img = Image.open('photo.jpg') 
  
img.thumbnail((30, 30), Image.ANTIALIAS)  
  
# bicubic used for interpolation 
imgplot = plt.imshow(img, interpolation ='bicubic')

# %% [markdown]
#  ‘sinc’ value is used for interpolation.

# %%
img = Image.open('photo.jpg') 
  
img.thumbnail((30, 30), Image.ANTIALIAS) 
  
# sinc used for interpolation 
imgplot = plt.imshow(img, interpolation ='sinc')
